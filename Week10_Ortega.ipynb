# %% [markdown]
# <a href="https://colab.research.google.com/github/carlyawasap/CHEAT-CODEEE/blob/main/Week10_Ortega.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

data = {
  'student_name' : ['Miguel', 'janelle', 'lovely', 'dolores', 'crysthel', 'jarrent', 'paulo', 'james', 'liam', 'lodoy', 'ezekiel', 'yeth', 'jocelyn', 'rochelle', 'denden', 'roniel', 'emma', 'jojo', 'jm', 'donald'],
  'study_hours' : [1,2,3,4,5,6,7,8,8,9,10,1,2,3,4,5,6,7,7,7],
  'attendance_rate' : [60,65,70,75,80,78,85,88,90,92,95,93,97,99,55,62,72,68,82,90],

}

df = pd.DataFrame(data)
print(df[["student_name", "study_hours", "attendance_rate"]])
# Out:
#    student_name  study_hours  attendance_rate
# 0        Miguel            1               60
# 1       janelle            2               65
# 2        lovely            3               70
# 3       dolores            4               75
# 4      crysthel            5               80
# 5       jarrent            6               78
# 6         paulo            7               85
# 7         james            8               88
# 8          liam            8               90
# 9         lodoy            9               92
# 10      ezekiel           10               95
# 11         yeth            1               93
# 12      jocelyn            2               97
# 13     rochelle            3               99
# 14       denden            4               55
# 15       roniel            5               62
# 16         emma            6               72
# 17         jojo            7               68
# 18           jm            7               82
# ...

# %% [markdown]
# step 2 -Scale the features

# %%
from sklearn.preprocessing import StandardScaler

X = df[['study_hours', 'attendance_rate']]

scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)
print(X_scaled[:5])
# Out:
# [[-1.63130065 -1.52055974]
#  [-1.2474652  -1.13658   ]
#  [-0.86362975 -0.75260027]
#  [-0.47979431 -0.36862054]
#  [-0.09595886  0.01535919]]

# %% [markdown]
# **Step 3** - K Means Clustering

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=2, random_state=42, n_init=10)
df['cluster'] = kmeans.fit_predict(X_scaled)
print(df[["student_name", "study_hours", "attendance_rate", "cluster"]])
# Out:
#    student_name  study_hours  attendance_rate  cluster
# 0        Miguel            1               60        0
# 1       janelle            2               65        0
# 2        lovely            3               70        0
# 3       dolores            4               75        0
# 4      crysthel            5               80        1
# 5       jarrent            6               78        1
# 6         paulo            7               85        1
# 7         james            8               88        1
# 8          liam            8               90        1
# 9         lodoy            9               92        1
# 10      ezekiel           10               95        1
# 11         yeth            1               93        1
# 12      jocelyn            2               97        1
# 13     rochelle            3               99        1
# 14       denden            4               55        0
# 15       roniel            5               62        0
# ...

# %% [markdown]
# **Step 4**- Interpret the clusters

# %%
centers_original = scaler.inverse_transform(kmeans.cluster_centers_)
for i, c in enumerate(centers_original):
  print(f'cluster {i}: study hours = {c[0]:.1f}, Attendance rate = {c[1]:.1f}')
# Out:
# cluster 0: study hours = 4.0, Attendance rate = 65.9
# cluster 1: study hours = 6.1, Attendance rate = 89.1

# %% [markdown]
# **Step 5**-
